# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd 
# %matplotlib inline

# %%
#  Origem dos Dados

import csv
data = pd.read_csv('PIB-Brasil.csv', sep=';', encoding='cp1252')
data
# Out:
#     Data  1207 - PIB em BRL correntes - BRL  \
# 0   1962                       0.000000e+00
# 1   1963                       0.000000e+00
# 2   1964                       1.000000e-02
# 3   1965                       2.000000e-02
# 4   1966                       2.000000e-02
# 5   1967                       3.000000e-02
# 6   1968                       4.000000e-02
# 7   1969                       6.000000e-02
# 8   1970                       7.000000e-02
# 9   1971                       9.000000e-02
# 10  1972                       1.300000e-01
# 11  1973                       1.900000e-01
# 12  1974                       2.700000e-01
# 13  1975                       3.800000e-01
# 14  1976                       5.900000e-01
# 15  1977                       9.100000e-01
# 16  1978                       1.320000e+00
# 17  1979                       2.170000e+00
# 18  1980                       4.550000e+00
# 19  1981                       8.730000e+00
# ...

# %%
ano = [1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979,
       1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
       1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
       2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
       2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
       2020, 2021]

ano = pd.Series(ano)

pib = [1.460, 1.625, 1.819, 2.073, 2.242, 2.358, 2.600, 2.729, 2.864, 3.058,
       3.340, 3.198, 3.225, 3.130, 3.299, 3.559, 3.825, 3.960, 3.958, 4.083,
       3.905, 3.945, 3.924, 4.117, 4.358, 4.542, 5.172, 5.347, 5.365, 5.390,
       5.627, 5.705, 5.879, 5.946, 6.289, 6.490, 6.747, 7.157, 7.522, 7.512,
       8.078, 8.399, 8.560, 8.817, 8.862, 8.548, 8.268, 8.377, 8.526, 8.631,
       8.296, 8.679]

pib = pd.Series(pib)

# %%
pib_agro = [0.243, 0.268, 0.278, 0.279, 0.282, 0.301, 0.307, 0.345, 0.335, 0.350,
            0.384, 0.416, 0.416, 0.416, 0.426, 0.467, 0.428, 0.493, 0.499, 0.513,
            0.497, 0.503, 0.529, 0.533, 0.570, 0.603, 0.694, 0.701, 0.728, 0.776,
            0.801, 0.844, 0.902, 0.971, 0.989, 1.007, 1.060, 1.099, 1.168, 1.144,
            1.217, 1.284, 1.264, 1.365, 1.408, 1.447, 1.378, 1.555, 1.582, 1.600,
            1.636, 1.648]

pib_agro = pd.Series(pib_agro)

pib_indust = [0.745, 0.833, 0.952, 1.114, 1.208, 1.267, 1.412, 1.458, 1.548, 1.651,
              1.804, 1.653, 1.654, 1.562, 1.660, 1.795, 1.999, 2.023, 1.976, 2.034,
              1.877, 1.881, 1.806, 1.948, 2.094, 2.193, 2.478, 2.591, 2.546, 2.482,
              2.603, 2.590, 2.660, 2.647, 2.860, 2.937, 3.014, 3.216, 3.362, 3.260,
              3.582, 3.726, 3.756, 3.826, 3.780, 3.544, 3.397, 3.342, 3.379, 3.382,
              3.220, 3.396]

pib_indust = pd.Series(pib_indust)

pib_servic = [0.472, 0.525, 0.590, 0.682, 0.753, 0.791, 0.881, 0.926, 0.982, 1.057,
              1.153, 1.130, 1.155, 1.153, 1.214, 1.297, 1.398, 1.445, 1.483, 1.536,
              1.532, 1.562, 1.589, 1.637, 1.694, 1.747, 2.000, 2.055, 2.092, 2.132,
              2.224, 2.272, 2.318, 2.328, 2.441, 2.547, 2.674, 2.843, 2.992, 3.108,
              3.279, 3.389, 3.541, 3.627, 3.675, 3.556, 3.493, 3.480, 3.566, 3.648,
              3.439, 3.635]

pib_servic = pd.Series(pib_servic)

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

plt.style.use('ggplot')

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 9
fig_size[1] = 4

plt.plot(ano, pib, color='black', label='PIB')
plt.plot(ano, pib_agro, color='green', label='PIB - Agricultura')
plt.plot(ano, pib_indust, color='gray', label='PIB - Indústria')
plt.plot(ano, pib_servic, color='blue', label='PIB - Serviços')

plt.title("PIB Brasil [R$ do ano retrasado]")
plt.xlabel("Ano")
plt.ylabel("PIB")
plt.yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
           ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Desacoplando Figura (*Figure*) e Eixo (*Axle*)

mpl.rcParams.update(mpl.rcParamsDefault)

plt.style.use('ggplot')

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 9
fig_size[1] = 4

fig, ax = plt.subplots()

ax.plot(ano, pib, color='black', label='PIB')
ax.plot(ano, pib_agro, color='green', label='PIB - Agricultura')
ax.plot(ano, pib_indust, color='gray', label='PIB - Indústria')
ax.plot(ano, pib_servic, color='blue', label='PIB - Serviços')

ax.set_title("PIB Brasil [R$ do ano retrasado]")
ax.set_xlabel("Ano")
ax.set_ylabel("PIB")
ax.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
              ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

ax.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1)
ax1.plot([1,2,3,4,5],[1,3,2,4,5], color='blue')
ax2.plot([1,2,3,4,5],[5,3,2,4,1], color='red')
plt.show()

# %%
# Desacoplando Figura (*Figure*) e Eixo (*Axle*)

mpl.rcParams.update(mpl.rcParamsDefault)

plt.style.use('ggplot')

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 9
fig_size[1] = 5

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1)

ax1.plot(ano, pib, color='black', label='PIB')


ax1.legend()
ax1.set_title("PIB Brasil [R$ do ano retrasado]")
ax1.set_xlabel("Ano")
ax1.set_ylabel("PIB")
ax1.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

ax2.plot(ano, pib_agro, color='green', label='PIB - Agricultura')
ax2.plot(ano, pib_indust, color='gray', label='PIB - Indústria')
ax2.plot(ano, pib_servic, color='blue', label='PIB - Serviços')


ax2.legend()
ax2.set_title('PIB Brasil [R$ ano retrasado]')
ax2.set_xlabel('Ano')
ax2.set_ylabel('PIB')
ax2.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Melhoramento  do Gráfico

mpl.rcParams.update(mpl.rcParamsDefault)

plt.style.use('ggplot')

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 9
fig_size[1] = 5

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)

ax1.plot(ano, pib, color='black', label='PIB')


ax1.legend()
ax1.set_title("PIB Brasil [R$ do ano retrasado]")
# ax1.set_xlabel("Ano")
ax1.set_ylabel("PIB")
ax1.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

ax2.plot(ano, pib_agro, color='green', label='PIB - Agricultura')
ax2.plot(ano, pib_indust, color='gray', label='PIB - Indústria')
ax2.plot(ano, pib_servic, color='blue', label='PIB - Serviços')


ax2.legend()
# ax2.set_title('PIB Brasil [R$ ano retrasado]')
ax2.set_xlabel('Ano')
ax2.set_ylabel('PIB')
ax2.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Melhoramento  do Gráfico

mpl.rcParams.update(mpl.rcParamsDefault)

plt.style.use('ggplot')

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 9
fig_size[1] = 5

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True)

ax1.plot(ano, pib, color='black', label='PIB')


ax1.legend()
ax1.set_title("PIB Brasil [R$ do ano retrasado]")
ax1.set_ylabel("PIB")
ax1.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

width = 0.25


ax2.bar(ano - width, pib_agro, color='green',
        label='PIB - Agricultura', width=width)
ax2.bar(ano, pib_indust, color='gray', label='PIB - Indústria', width=width)
ax2.bar(ano + width, pib_servic, color='blue',
        label='PIB - Serviços', width=width)


ax2.legend()
# ax2.set_title('PIB Brasil [R$ ano retrasado]')
ax2.set_xlabel('Ano')
ax2.set_ylabel('PIB')
ax2.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Melhoramento  do Gráfico
# Desacoplando Figura

mpl.rcParams.update(mpl.rcParamsDefault)

plt.style.use('ggplot')

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 9
fig_size[1] = 5

fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

ax1.plot(ano, pib, color='black', label='PIB')


ax1.legend()
ax1.set_title("PIB Brasil [R$ do ano retrasado]")
ax1.set_ylabel("PIB")
ax1.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

width = 0.25


ax2.bar(ano - width, pib_agro, color='green',
        label='PIB - Agricultura', width=width)
ax2.bar(ano, pib_indust, color='gray', label='PIB - Indústria', width=width)
ax2.bar(ano + width, pib_servic, color='blue',
        label='PIB - Serviços', width=width)


ax2.legend()
# ax2.set_title('PIB Brasil [R$ ano retrasado]')
ax2.set_xlabel('Ano')
ax2.set_ylabel('PIB')
ax2.set_yticks([1, 2, 3, 4, 5, 6, 7, 8, 9],
               ["1Tri", "2Tri", "3Tri", "4Tri", "5Tri", "6Tri", "7Tri", "8Tri", "9Tri"])

plt.grid(True)
plt.tight_layout()
plt.show()

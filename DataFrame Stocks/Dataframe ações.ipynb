# %%
# Pesquisa de dados no inicio de 2023
# Feito no (inicio) de 2023, subindo para o github (agora) >Revisando

import pandas as pd

Hypo_US_Shares = pd.DataFrame({'Name': ['Advanced Micro Devices', 'McDonalds Corporation', 'Netflix', 'NVIDIA', 'GOOGLE'],

                               'Category': ['Technology', 'Consumer Cyclical Sector', 'Technology Streaming', 'Technology', 'Technology'],

                               'Ticker': ['AMD', 'MCD', 'NFLX', 'NVDA', 'GOOGL'],

                               'NYSE_Governance': ['High level', 'Middle level', 'High level', 'Middle level', 'Middle level'],

                               # O valor de mercado das 4 primeiras ações são avaliadas em (Bilhões), a GOOGL é avaliada em (Trilhões).
                               'MarketCap': [114.478, 196.941, 148.112, 421.123, 1.197],

                               'NetRevenue_12M': [2.273, 5.913, 5.044, 5.956, 66.99]})  # Dados da origem da receita líquida foi no ano fiscal  no final de 2022.

# %%
Hypo_US_Shares
# Out:
#                      Name                  Category Ticker NYSE_Governance  \
# 0  Advanced Micro Devices                Technology    AMD      High level
# 1   McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
# 2                 Netflix      Technology Streaming   NFLX      High level
# 3                  NVIDIA                Technology   NVDA    Middle level
# 4                  GOOGLE                Technology  GOOGL    Middle level
#
#    MarketCap  NetRevenue_12M
# 0    114.478           2.273
# 1    196.941           5.913
# 2    148.112           5.044
# 3    421.123           5.956
# 4      1.197          66.990

# %%
Hypo_US_Shares.columns.tolist()
# Out:
# ['Name',
#  'Category',
#  'Ticker',
#  'NYSE_Governance',
#  'MarketCap',
#  'NetRevenue_12M']

# %%
Hypo_US_Shares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             5 non-null      object
#  1   Category         5 non-null      object
#  2   Ticker           5 non-null      object
#  3   NYSE_Governance  5 non-null      object
#  4   MarketCap        5 non-null      float64
#  5   NetRevenue_12M   5 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 368.0+ bytes

# %%
print(Hypo_US_Shares.values)
# Out:
# [['Advanced Micro Devices' 'Technology' 'AMD' 'High level' 114.478 2.273]
#  ['McDonalds Corporation' 'Consumer Cyclical Sector' 'MCD' 'Middle level'
#   196.941 5.913]
#  ['Netflix' 'Technology Streaming' 'NFLX' 'High level' 148.112 5.044]
#  ['NVIDIA' 'Technology' 'NVDA' 'Middle level' 421.123 5.956]
#  ['GOOGLE' 'Technology' 'GOOGL' 'Middle level' 1.197 66.99]]

# %%
# Copia
# Modificar esta tabela mais tarde.

Hypo_US_Shares2 = Hypo_US_Shares.copy()

# %%
Hypo_US_Shares2
# Out:
#                      Name                  Category Ticker NYSE_Governance  \
# 0  Advanced Micro Devices                Technology    AMD      High level
# 1   McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
# 2                 Netflix      Technology Streaming   NFLX      High level
# 3                  NVIDIA                Technology   NVDA    Middle level
# 4                  GOOGLE                Technology  GOOGL    Middle level
#
#    MarketCap  NetRevenue_12M
# 0    114.478           2.273
# 1    196.941           5.913
# 2    148.112           5.044
# 3    421.123           5.956
# 4      1.197          66.990

# %%
# Acessando Linhas, Colunas e Valores

Hypo_US_Shares2.iloc[3:]
# Out:
#      Name    Category Ticker NYSE_Governance  MarketCap  NetRevenue_12M
# 3  NVIDIA  Technology   NVDA    Middle level    421.123           5.956
# 4  GOOGLE  Technology  GOOGL    Middle level      1.197          66.990

# %%
Hypo_US_Shares2.iloc[0:2]
# Out:
#                      Name                  Category Ticker NYSE_Governance  \
# 0  Advanced Micro Devices                Technology    AMD      High level
# 1   McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
#
#    MarketCap  NetRevenue_12M
# 0    114.478           2.273
# 1    196.941           5.913

# %%
Hypo_US_Shares2.iloc[[4]]
# Out:
#      Name    Category Ticker NYSE_Governance  MarketCap  NetRevenue_12M
# 4  GOOGLE  Technology  GOOGL    Middle level      1.197           66.99

# %%
Hypo_US_Shares2.iloc[[0,2]]
# Out:
#                      Name              Category Ticker NYSE_Governance  \
# 0  Advanced Micro Devices            Technology    AMD      High level
# 2                 Netflix  Technology Streaming   NFLX      High level
#
#    MarketCap  NetRevenue_12M
# 0    114.478           2.273
# 2    148.112           5.044

# %%
Hypo_US_Shares2.iloc[[False, False, True, True, True]]
# Out:
#       Name              Category Ticker NYSE_Governance  MarketCap  \
# 2  Netflix  Technology Streaming   NFLX      High level    148.112
# 3   NVIDIA            Technology   NVDA    Middle level    421.123
# 4   GOOGLE            Technology  GOOGL    Middle level      1.197
#
#    NetRevenue_12M
# 2           5.044
# 3           5.956
# 4          66.990

# %%
Hypo_US_Shares2.iloc[0:]
# Out:
#                      Name                  Category Ticker NYSE_Governance  \
# 0  Advanced Micro Devices                Technology    AMD      High level
# 1   McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
# 2                 Netflix      Technology Streaming   NFLX      High level
# 3                  NVIDIA                Technology   NVDA    Middle level
# 4                  GOOGLE                Technology  GOOGL    Middle level
#
#    MarketCap  NetRevenue_12M
# 0    114.478           2.273
# 1    196.941           5.913
# 2    148.112           5.044
# 3    421.123           5.956
# 4      1.197          66.990

# %%
Hypo_US_Shares2[['Name']]
# Out:
#                      Name
# 0  Advanced Micro Devices
# 1   McDonalds Corporation
# 2                 Netflix
# 3                  NVIDIA
# 4                  GOOGLE

# %%
Hypo_US_Shares2[['Ticker']]
# Out:
#   Ticker
# 0    AMD
# 1    MCD
# 2   NFLX
# 3   NVDA
# 4  GOOGL

# %%
Hypo_US_Shares2.loc[[False, True, False, False, True]]
# Out:
#                     Name                  Category Ticker NYSE_Governance  \
# 1  McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
# 4                 GOOGLE                Technology  GOOGL    Middle level
#
#    MarketCap  NetRevenue_12M
# 1    196.941           5.913
# 4      1.197          66.990

# %%
Hypo_US_Shares2.filter(like ='Name', axis = 1)
# Out:
#                      Name
# 0  Advanced Micro Devices
# 1   McDonalds Corporation
# 2                 Netflix
# 3                  NVIDIA
# 4                  GOOGLE

# %%
Hypo_US_Shares2.filter(like ='NetRevenue_12M', axis = 1)
# Out:
#    NetRevenue_12M
# 0           2.273
# 1           5.913
# 2           5.044
# 3           5.956
# 4          66.990

# %%
Hypo_US_Shares2.filter(items=['Name', 'NYSE_Governance'])
# Out:
#                      Name NYSE_Governance
# 0  Advanced Micro Devices      High level
# 1   McDonalds Corporation    Middle level
# 2                 Netflix      High level
# 3                  NVIDIA    Middle level
# 4                  GOOGLE    Middle level

# %%
Hypo_US_Shares2.query('NetRevenue_12M >=5.500')
# Out:
#                     Name                  Category Ticker NYSE_Governance  \
# 1  McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
# 3                 NVIDIA                Technology   NVDA    Middle level
# 4                 GOOGLE                Technology  GOOGL    Middle level
#
#    MarketCap  NetRevenue_12M
# 1    196.941           5.913
# 3    421.123           5.956
# 4      1.197          66.990

# %%
# Nova Coluna no DataFrame

Hypo_US_Shares2 ['Market Open']  = [71.01, 266.96, 322.81 ,173.91, 90.99]

# %%
Hypo_US_Shares2
# Out:
#                      Name                  Category Ticker NYSE_Governance  \
# 0  Advanced Micro Devices                Technology    AMD      High level
# 1   McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
# 2                 Netflix      Technology Streaming   NFLX      High level
# 3                  NVIDIA                Technology   NVDA    Middle level
# 4                  GOOGLE                Technology  GOOGL    Middle level
#
#    MarketCap  NetRevenue_12M  Market Open
# 0    114.478           2.273        71.01
# 1    196.941           5.913       266.96
# 2    148.112           5.044       322.81
# 3    421.123           5.956       173.91
# 4      1.197          66.990        90.99

# %% [markdown]
# # Este é um link para a [Yahoo Finance] (https://br.financas.yahoo.com/).

# %%
# Flutuações,  quantidade de ações no mercado
#  Em Bilhões e Milhões de ações circulante.

# A Google tem muita mais que isso, só que ia ficar em notação cientifica na tabela  

Hypo_US_Shares2['MarketCap']/ Hypo_US_Shares2['Market Open']
# Out:
# 0    1.612139
# 1    0.737717
# 2    0.458821
# 3    2.421500
# 4    0.013155
# dtype: float64

# %%
Hypo_US_Shares2['MarketCap']*1000/ Hypo_US_Shares2['Market Open']
# Out:
# 0    1612.139135
# 1     737.717261
# 2     458.820978
# 3    2421.499626
# 4      13.155292
# dtype: float64

# %%
Hypo_US_Shares2['current_S_amounts'] = round((Hypo_US_Shares2['MarketCap']*1000/Hypo_US_Shares2['Market Open']).astype('int'), 0)

# %% [markdown]
# # [Ações da Google toda Info ] (https://br.financas.yahoo.com/quote/GOOGL/key-statistics?p=GOOGL)
#
# # (Feito inicio de janeiro de 2023)
# # No DataFrame está em 13 Bilhões de ações circulantes

# %%
Hypo_US_Shares2
# Out:
#                      Name                  Category Ticker NYSE_Governance  \
# 0  Advanced Micro Devices                Technology    AMD      High level
# 1   McDonalds Corporation  Consumer Cyclical Sector    MCD    Middle level
# 2                 Netflix      Technology Streaming   NFLX      High level
# 3                  NVIDIA                Technology   NVDA    Middle level
# 4                  GOOGLE                Technology  GOOGL    Middle level
#
#    MarketCap  NetRevenue_12M  Market Open  current_S_amounts
# 0    114.478           2.273        71.01               1612
# 1    196.941           5.913       266.96                737
# 2    148.112           5.044       322.81                458
# 3    421.123           5.956       173.91               2421
# 4      1.197          66.990        90.99                 13
